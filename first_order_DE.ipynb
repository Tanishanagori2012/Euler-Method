# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanishanagori2012/Euler-Method/blob/main/first_order_DE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#euler method
from plotly.basedatatypes import BaseTraceHierarchyType
import plotly.graph_objects as go
import math
import plotly.express as px
import matplotlib.pyplot as plt

# %%
#Euler Method

t = []
for i in range(51):
  t.append(i/10)
#analytical solution 
lst2 = []
for k in range(len(t)):
  lst2.append(math.exp(t[k]))
plt.plot(t,lst2)
plt.show()

# %%
#numerical solution (Eyler method)
delta_t = 0.1
x_hat = 1
x_zero = 1
lst_x_hat = []
for j in range(len(t)): 
  x_new = x_hat * delta_t + x_hat
  x_hat  = x_new
  lst_x_hat.append(x_hat)
plt.plot(t,lst2 ,label = 'Analytical Solution')
plt.legend()
plt.plot(t,lst_x_hat ,label = 'Euler solution')
plt.legend()

# %%
dt = []
for i in range(51):
  dt.append(i/1000)

# to find error
error = []
for j in range(51):
  res = (lst2[j] - lst_x_hat[j])/lst2[j]
  error.append(res)

plt.plot(dt, error)
plt.show()

# Modified Euler method 
num_mid = [1]
dt = 0.1
for j in range(50):
  x1 = num_mid[j] + dt*(num_mid[j] + dt*num_mid[j]/2)
  num_mid.append(x1)
plt.plot(t, num_mid)
plt.show

#measure error between Euler(midpoint method) and analytical method
dt = []
for i in range(51):
  dt.append(i/1000)

# to find error
error = []
for j in range(51):
  res = abs(lst2[j] - num_mid[j])/num_mid[j]
  error.append(res)

plt.plot(dt, error)
plt.show()
